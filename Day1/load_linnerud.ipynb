# %% [markdown]
# # load_linnerud

# %%
from sklearn.datasets import load_linnerud
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
data = load_linnerud()

# %%
print(type(data))
# Out:
# <class 'sklearn.utils._bunch.Bunch'>

# %%
print(data.keys())
# Out:
# dict_keys(['data', 'feature_names', 'target', 'target_names', 'frame', 'DESCR', 'data_filename', 'target_filename', 'data_module'])

# %%
print(type(data.data))
# Out:
# <class 'numpy.ndarray'>

# %%
print(data.feature_names)
# Out:
# ['Chins', 'Situps', 'Jumps']

# %%
print(data.data)
# Out:
# [[  5. 162.  60.]
#  [  2. 110.  60.]
#  [ 12. 101. 101.]
#  [ 12. 105.  37.]
#  [ 13. 155.  58.]
#  [  4. 101.  42.]
#  [  8. 101.  38.]
#  [  6. 125.  40.]
#  [ 15. 200.  40.]
#  [ 17. 251. 250.]
#  [ 17. 120.  38.]
#  [ 13. 210. 115.]
#  [ 14. 215. 105.]
#  [  1.  50.  50.]
#  [  6.  70.  31.]
#  [ 12. 210. 120.]
#  [  4.  60.  25.]
#  [ 11. 230.  80.]
#  [ 15. 225.  73.]
#  [  2. 110.  43.]]

# %%
print(data.DESCR)
# Out:
# .. _linnerrud_dataset:
#
# Linnerrud dataset
# -----------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20
# :Number of Attributes: 3
# :Missing Attribute Values: None
#
# The Linnerud dataset is a multi-output regression dataset. It consists of three
# exercise (data) and three physiological (target) variables collected from
# twenty middle-aged men in a fitness club:
#
# - *physiological* - CSV containing 20 observations on 3 physiological variables:
#    Weight, Waist and Pulse.
# - *exercise* - CSV containing 20 observations on 3 exercise variables:
#    Chins, Situps and Jumps.
#
# .. dropdown:: References
#
#    * Tenenhaus, M. (1998). La regression PLS: theorie et pratique. Paris:
#      Editions Technic.

# %%
print(data.target)
# Out:
# [[191.  36.  50.]
#  [189.  37.  52.]
#  [193.  38.  58.]
#  [162.  35.  62.]
#  [189.  35.  46.]
#  [182.  36.  56.]
#  [211.  38.  56.]
#  [167.  34.  60.]
#  [176.  31.  74.]
#  [154.  33.  56.]
#  [169.  34.  50.]
#  [166.  33.  52.]
#  [154.  34.  64.]
#  [247.  46.  50.]
#  [193.  36.  46.]
#  [202.  37.  62.]
#  [176.  37.  54.]
#  [157.  32.  52.]
#  [156.  33.  54.]
#  [138.  33.  68.]]

# %%
print(data.target_names)
# Out:
# ['Weight', 'Waist', 'Pulse']

# %%
df = pd.DataFrame(data=data.data, columns=data.feature_names)
df['Weight'] = data.target[:, 0]
df['Waist'] = data.target[:, 1]
df['Pulse'] = data.target[:, 2]

# %%
df.head()
# Out:
#    Chins  Situps  Jumps  Weight  Waist  Pulse
# 0    5.0   162.0   60.0   191.0   36.0   50.0
# 1    2.0   110.0   60.0   189.0   37.0   52.0
# 2   12.0   101.0  101.0   193.0   38.0   58.0
# 3   12.0   105.0   37.0   162.0   35.0   62.0
# 4   13.0   155.0   58.0   189.0   35.0   46.0

# %%
df.tail()
# Out:
#     Chins  Situps  Jumps  Weight  Waist  Pulse
# 15   12.0   210.0  120.0   202.0   37.0   62.0
# 16    4.0    60.0   25.0   176.0   37.0   54.0
# 17   11.0   230.0   80.0   157.0   32.0   52.0
# 18   15.0   225.0   73.0   156.0   33.0   54.0
# 19    2.0   110.0   43.0   138.0   33.0   68.0

# %%
df.describe()
# Out:
#            Chins      Situps      Jumps      Weight      Waist      Pulse
# count  20.000000   20.000000   20.00000   20.000000  20.000000  20.000000
# mean    9.450000  145.550000   70.30000  178.600000  35.400000  56.100000
# std     5.286278   62.566575   51.27747   24.690505   3.201973   7.210373
# min     1.000000   50.000000   25.00000  138.000000  31.000000  46.000000
# 25%     4.750000  101.000000   39.50000  160.750000  33.000000  51.500000
# 50%    11.500000  122.500000   54.00000  176.000000  35.000000  55.000000
# 75%    13.250000  210.000000   85.25000  191.500000  37.000000  60.500000
# max    17.000000  251.000000  250.00000  247.000000  46.000000  74.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Chins   20 non-null     float64
#  1   Situps  20 non-null     float64
#  2   Jumps   20 non-null     float64
#  3   Weight  20 non-null     float64
#  4   Waist   20 non-null     float64
#  5   Pulse   20 non-null     float64
# dtypes: float64(6)
# memory usage: 1.1 KB

# %%
print(df.isnull().sum())
# Out:
# Chins     0
# Situps    0
# Jumps     0
# Weight    0
# Waist     0
# Pulse     0
# dtype: int64

# %%
df.plot()
# Out:
# <Axes: >

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data_utils

# %%
class LinnerudModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(LinnerudModel, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 16),
            nn.ReLU(),
            nn.Linear(16, output_size)
        )
        
    def forward(self, x):
        output = self.model(x)
        return output

# %%
X = torch.Tensor(data.data)
y = torch.Tensor(data.target)

# %%
print(X)
# Out:
# tensor([[  5., 162.,  60.],
#         [  2., 110.,  60.],
#         [ 12., 101., 101.],
#         [ 12., 105.,  37.],
#         [ 13., 155.,  58.],
#         [  4., 101.,  42.],
#         [  8., 101.,  38.],
#         [  6., 125.,  40.],
#         [ 15., 200.,  40.],
#         [ 17., 251., 250.],
#         [ 17., 120.,  38.],
#         [ 13., 210., 115.],
#         [ 14., 215., 105.],
#         [  1.,  50.,  50.],
#         [  6.,  70.,  31.],
#         [ 12., 210., 120.],
#         [  4.,  60.,  25.],
#         [ 11., 230.,  80.],
#         [ 15., 225.,  73.],
#         [  2., 110.,  43.]])

# %%
print(y)
# Out:
# tensor([[191.,  36.,  50.],
#         [189.,  37.,  52.],
#         [193.,  38.,  58.],
#         [162.,  35.,  62.],
#         [189.,  35.,  46.],
#         [182.,  36.,  56.],
#         [211.,  38.,  56.],
#         [167.,  34.,  60.],
#         [176.,  31.,  74.],
#         [154.,  33.,  56.],
#         [169.,  34.,  50.],
#         [166.,  33.,  52.],
#         [154.,  34.,  64.],
#         [247.,  46.,  50.],
#         [193.,  36.,  46.],
#         [202.,  37.,  62.],
#         [176.,  37.,  54.],
#         [157.,  32.,  52.],
#         [156.,  33.,  54.],
#         [138.,  33.,  68.]])

# %%
import numpy as np
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) # train과 test를 8:2로 분할

# %%
model = LinnerudModel(3, 3)

# %%
n = 0
y = model(X_train[n]).detach() # 더 이상 연산을 추적하지 않는다
print(y, y_train[n])
# Out:
# tensor([ 11.3926,   2.7906, -11.0838]) tensor([193.,  36.,  46.])

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
print(model)
# Out:
# LinnerudModel(
#   (model): Sequential(
#     (0): Linear(in_features=3, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=3, bias=True)
#   )
# )

# %%
criterion = nn.MSELoss()

n_epochs = 100 # 100회 학습

avg_loss = 0 
for epoch in range(n_epochs):
    for i in range(len(X_train)):
        y = torch.unsqueeze(model(X_train[i]), dim=0)
        target = torch.unsqueeze(y_train[i], dim=0)
        loss = criterion(y, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        avg_loss += loss.data
    avg_loss /= len(X_train)
    if epoch % 10 == 0:
        print('epoch {}th loss: {}'.format(epoch, avg_loss))
# Out:
# epoch 0th loss: 10324.447265625
# epoch 10th loss: 2921.768310546875
# epoch 20th loss: 2670.822021484375
# epoch 30th loss: 2632.808349609375
# epoch 40th loss: 2599.873046875
# epoch 50th loss: 2569.116455078125
# epoch 60th loss: 2540.362548828125
# epoch 70th loss: 2512.5537109375
# epoch 80th loss: 2486.828857421875
# epoch 90th loss: 2461.8642578125

# %%
n = 0
y = model(X_train[n]).detach() # 더 이상 연산을 추적하지 않는다
print(y, y_train[n])
# Out:
# tensor([81.1402, 16.5000, 25.3346]) tensor([193.,  36.,  46.])

# %%
model = LinnerudModel(3, 3)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

n_epochs = 10000 # 10000회 학습

avg_loss = 0 
for epoch in range(n_epochs):
    y = model(X_train)
    loss = criterion(y, y_train).sum()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if epoch % 1000 == 0:
        print('epoch {}th loss: {}'.format(epoch, loss.data))
# Out:
# epoch 0th loss: 11150.98046875
# epoch 1000th loss: 2250.52490234375
# epoch 2000th loss: 2094.525146484375
# epoch 3000th loss: 1693.5958251953125
# epoch 4000th loss: 1032.58740234375
# epoch 5000th loss: 533.1953735351562
# epoch 6000th loss: 240.8274383544922
# epoch 7000th loss: 114.64965057373047
# epoch 8000th loss: 91.13379669189453
# epoch 9000th loss: 90.1796875

# %%
n = 4
y = model(X_train[n]).detach() # 더 이상 연산을 추적하지 않는다
print(y, y_train[n])
# Out:
# tensor([169.3899,  34.9452,  58.8288]) tensor([138.,  33.,  68.])

# %%
model = LinnerudModel(3, 3)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)
criterion = nn.MSELoss()

n_epochs = 50000 # 50000회 학습

list_training_loss = []
list_test_loss = []

for epoch in range(n_epochs):
    model.train()
    y = model(X_train)
    loss = criterion(y, y_train).sum()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if epoch % 5000 == 0:
        model.eval()
        y_pred = model(X_test)
        test_loss = criterion(y_pred, y_test).sum()
        print('epoch {}th training loss: {} test loss: {}'.format(epoch, loss.data, test_loss.data))
        list_training_loss.append(loss.data)
        list_test_loss.append(test_loss.data)
# Out:
# epoch 0th training loss: 13105.5400390625 test loss: 12519.2041015625
# epoch 5000th training loss: 1894.3037109375 test loss: 9437.1640625
# epoch 10000th training loss: 249.82566833496094 test loss: 2505.559814453125
# epoch 15000th training loss: 140.3319549560547 test loss: 1338.5357666015625
# epoch 20000th training loss: 140.09288024902344 test loss: 1151.77294921875
# epoch 25000th training loss: 139.58377075195312 test loss: 1078.2371826171875
# epoch 30000th training loss: 139.37774658203125 test loss: 1022.135009765625
# epoch 35000th training loss: 139.34007263183594 test loss: 1002.045166015625
# epoch 40000th training loss: 139.33602905273438 test loss: 993.6527709960938
# epoch 45000th training loss: 139.3339385986328 test loss: 993.08251953125

# %%
import matplotlib.pyplot as plt

plt.plot(list_training_loss, label='training')
plt.plot(list_test_loss, label='test')
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score

with torch.no_grad():
    y_pred = model(X_test)
    score = r2_score(y_test, y_pred)
    print(score)
# Out:
# -21.95400320866982

# %%
class MAPELoss(nn.Module):
    def __init__(self):
        super(MAPELoss, self).__init__()

    def forward(self, y_pred, y_true):
        epsilon = 1e-8  
        loss = torch.mean(torch.abs((y_true - y_pred) / (y_true + epsilon)))
        return loss * 100  
    
mape_loss = MAPELoss()
y_pred = model(X_test).squeeze()
loss_value = mape_loss(y_pred, y_test)
print(f"MAPE Loss: {loss_value.item():.4f}%")
# Out:
# MAPE Loss: 22.4830%
