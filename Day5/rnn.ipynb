# %% [markdown]
# # RNN

# %% [markdown]
# ![rnn4.png](data:image/png;base64,...)

# %% [markdown]
# ![rnn1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![rnn2.png](data:image/png;base64,...)

# %% [markdown]
# ![rnn3.png](data:image/png;base64,...)
